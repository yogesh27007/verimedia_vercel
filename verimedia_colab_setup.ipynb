# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh27007/Verimedia/blob/main/verimedia_colab_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Verimedia - AI-Powered Media Forensics in Google Colab
#
# This notebook sets up and runs the Verimedia project in Google Colab. Verimedia is an advanced media verification and analysis platform using AI and deep learning.

# %% [markdown]
# ## Step 1: Clone the Repository

# %%
# !git clone https://github.com/yogesh27007/Verimedia.git
# %cd Verimedia

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# Install Node.js and npm
# !curl -fsSL https://deb.nodesource.com/setup_18.x | sudo -E bash -
# !sudo apt-get install -y nodejs

# Verify installation
# !node --version
# !npm --version

# %%
# Install project dependencies
# !npm install

# %% [markdown]
# ## Step 3: Install Python Dependencies

# %%
# Install required Python packages
# !pip install --upgrade pip
# !pip install onnxruntime opencv-python numpy pillow scipy scikit-image

# %% [markdown]
# ## Step 4: Build the Project

# %%
# Build the React/Vite project
# !npm run build

# %% [markdown]
# ## Step 5: Verify Installation
#
# The project is now built and ready. Here's what's available:
#
# ### Project Structure:
# - **Frontend**: React app with forensic analysis visualization
# - **Modules**:
#   - AI Classifier: Machine learning classification
#   - ELA Engine: Error Level Analysis
#   - Noise Analyzer: Image noise detection
#   - Video Processor: Video forensics
#   - Fusion Engine: Multi-modal analysis
#   - C2PA Parser: Content authentication
#
# ### Using in Colab:
# You can now import and use the Verimedia modules in Python cells.

# %%
# Verify the build was successful
import os

# Check build output
if os.path.exists('dist'):
    print("✓ Build successful! Files in dist/:")
    for item in os.listdir('dist'):
        print(f"  - {item}")
else:
    print("Build directory not found")

# List source modules
print("\n✓ Available modules in src/modules/:")
modules_path = 'src/modules'
for file in os.listdir(modules_path):
    if file.endswith('.js'):
        print(f"  - {file}")

# %% [markdown]
# ## Example: Working with Images
#
# You can now work with images and apply forensic analysis.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# Upload an image to analyze
print("Upload an image to analyze:")
uploaded = files.upload()

if uploaded:
    for filename in uploaded.keys():
        print(f"\nAnalyzing: {filename}")
        img = Image.open(filename)
        
        # Display the image
        plt.figure(figsize=(10, 6))
        plt.imshow(img)
        plt.title(f"Uploaded Image: {filename}")
        plt.axis('off')
        plt.show()
        
        # Get image properties
        arr = np.array(img)
        print(f"\nImage Properties:")
        print(f"  Size: {img.size}")
        print(f"  Mode: {img.mode}")
        print(f"  Shape: {arr.shape}")

# %% [markdown]
# ## Next Steps
#
# 1. **Explore the modules**: Check out the individual analysis modules in `src/modules/`
# 2. **Train models**: Use `public/train_verimedia_model.py` for model training
# 3. **Analyze media**: Apply forensic analysis to your media files
# 4. **Generate reports**: Create detailed forensic analysis reports
#
# For more information, visit: https://github.com/yogesh27007/Verimedia
