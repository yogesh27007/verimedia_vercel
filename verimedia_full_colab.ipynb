# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh27007/Verimedia/blob/main/verimedia_full_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# <style>
# :root {
#   --primary-dark: #0a1428;
#   --secondary-dark: #1a2a4e;
#   --accent-teal: #00d4ff;
#   --accent-blue: #0099ff;
#   --accent-red: #ff3d3d;
#   --accent-green: #00ff88;
#   --text-primary: #e8e8e8;
#   --text-secondary: #a8b8d8;
#   --border-color: #2a4a7e;
# }
#
# .verimedia-header {
#   background: linear-gradient(135deg, var(--primary-dark) 0%, var(--secondary-dark) 100%);
#   border-left: 4px solid var(--accent-teal);
#   padding: 30px;
#   border-radius: 8px;
#   margin-bottom: 30px;
#   border: 1px solid var(--border-color);
# }
#
# .verimedia-title {
#   color: var(--accent-teal);
#   font-size: 32px;
#   font-weight: 700;
#   margin: 0 0 10px 0;
#   text-shadow: 0 0 10px rgba(0, 212, 255, 0.3);
# }
#
# .verimedia-subtitle {
#   color: var(--text-secondary);
#   font-size: 14px;
#   margin: 10px 0 20px 0;
#   letter-spacing: 1px;
# }
#
# .feature-grid {
#   display: grid;
#   grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
#   gap: 15px;
#   margin-top: 20px;
# }
#
# .feature-item {
#   background: rgba(0, 153, 255, 0.05);
#   border: 1px solid var(--accent-blue);
#   padding: 12px;
#   border-radius: 4px;
#   color: var(--text-primary);
#   font-size: 12px;
# }
#
# .step-header {
#   background: var(--secondary-dark);
#   border-left: 4px solid var(--accent-teal);
#   padding: 15px 20px;
#   margin: 25px 0 15px 0;
#   border-radius: 4px;
#   border: 1px solid var(--border-color);
#   color: var(--accent-teal);
#   font-size: 16px;
#   font-weight: 600;
#   letter-spacing: 0.5px;
# }
#
# .status-indicator {
#   display: inline-block;
#   width: 8px;
#   height: 8px;
#   border-radius: 50%;
#   margin-right: 8px;
# }
#
# .status-active {
#   background: var(--accent-green);
#   box-shadow: 0 0 10px rgba(0, 255, 136, 0.5);
# }
#
# .status-loading {
#   background: var(--accent-teal);
#   box-shadow: 0 0 10px rgba(0, 212, 255, 0.5);
# }
#
# .status-error {
#   background: var(--accent-red);
#   box-shadow: 0 0 10px rgba(255, 61, 61, 0.5);
# }
# </style>
#
# <div class="verimedia-header">
#   <h1 class="verimedia-title">⚡ VERIMEDIA FORENSICS PLATFORM</h1>
#   <p class="verimedia-subtitle">AI-POWERED MEDIA VERIFICATION & ANALYSIS SYSTEM</p>
#
#   <div class="feature-grid">
#     <div class="feature-item">🎬 React/Vite Web Application</div>
#     <div class="feature-item">🔗 ngrok Tunneling Gateway</div>
#     <div class="feature-item">🤖 Neural Network Analysis</div>
#     <div class="feature-item">📊 Multi-Modal Forensics</div>
#     <div class="feature-item">📈 Real-Time Processing</div>
#     <div class="feature-item">🖼️ Interactive Evidence Viewer</div>
#   </div>
# </div>

# %% [markdown]
# ## Step 1️⃣ Clone Repository & Install Dependencies

# %%
import os
import subprocess

print("Cloning Verimedia repository...")
# !git clone https://github.com/yogesh27007/Verimedia.git
os.chdir('Verimedia')
print("\n✓ Repository cloned successfully")

# %%
#@title Install Node.js and NPM
import subprocess

print("Installing Node.js...")
# !curl -fsSL https://deb.nodesource.com/setup_18.x | sudo -E bash -
# !sudo apt-get install -y nodejs -qq

print("\nVerifying installation...")
# !echo "Node version: $(node --version)"
# !echo "NPM version: $(npm --version)"
print("✓ Node.js and NPM installed successfully")

# %%
#@title Install NPM Dependencies
print("Installing NPM dependencies...")
# !npm install --silent 2>&1 | tail -20
print("\n✓ NPM dependencies installed successfully")

# %%
## Step 2️⃣ Build the React Application

# %%
## Step 3️⃣ Start Live Server with ngrok
